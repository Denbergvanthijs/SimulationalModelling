# %% [markdown]
# # Simuleren van Beweging

# %%
import scripts.SimulerenVanBeweging as SVB
import scripts.Planeetbeweging as Planeet

# %%
t, x, v = SVB.forward_euler()
SVB.plot(t, x, v)

# %%
Planeet.plot()
